# %%
import pandas as pd

# %%
data = pd.read_csv("data/BlackFriday.csv")

# úprava product ID na integer
data['Product_ID'] = data['Product_ID'].apply(lambda x: int(str(x).lstrip("P").lstrip("0")))

# print some info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
# User_ID                       537577 non-null int64
# Product_ID                    537577 non-null int64
# Gender                        537577 non-null object
# Age                           537577 non-null object
# Occupation                    537577 non-null int64
# City_Category                 537577 non-null object
# Stay_In_Current_City_Years    537577 non-null object
# Marital_Status                537577 non-null int64
# Product_Category_1            537577 non-null int64
# Product_Category_2            370591 non-null float64
# Product_Category_3            164278 non-null float64
# Purchase                      537577 non-null int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 49.2+ MB

# %%
data.head(100)
# Out:
#     User_ID  Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001       69042      F   0-17          10             A
# 1   1000001      248942      F   0-17          10             A
# 2   1000001       87842      F   0-17          10             A
# 3   1000001       85442      F   0-17          10             A
# 4   1000002      285442      M    55+          16             C
# 5   1000003      193542      M  26-35          15             A
# 6   1000004      184942      M  46-50           7             B
# 7   1000004      346142      M  46-50           7             B
# 8   1000004       97242      M  46-50           7             B
# 9   1000005      274942      M  26-35          20             A
# 10  1000005      251242      M  26-35          20             A
# 11  1000005       14542      M  26-35          20             A
# 12  1000005       31342      M  26-35          20             A
# 13  1000005      145042      M  26-35          20             A
# ...

# %%
ref_list = ["www.google.com", "www.youtube.com", "www.facebook.com", "www.baidu.com", "www.wikipedia.org", "www.reddit.com", "www.yahoo.com", "www.qq.com", "www.taobao.com", "www.google.co.in", "www.amazon.com", "www.tmall.com", "www.twitter.com", "www.sohu.com", "www.instagram.com", "www.vk.com", "www.live.com", "www.jd.com", "www.sina.com.cn", "www.weibo.com", "www.yandex.ru", "www.360.cn", "www.google.co.jp", "www.google.co.uk", "www.list.tmall.com", "www.google.ru", "www.google.com.br", "www.netflix.com", "www.google.de", "www.google.com.hk", "www.pornhub.com", "www.twitch.tv", "www.google.fr", "www.linkedin.com", "www.yahoo.co.jp", "www.t.co", "www.csdn.net", "www.microsoft.com", "www.bing.com", "www.office.com", "www.ebay.com", "www.alipay.com", "www.xvideos.com", "www.google.it", "www.google.ca", "www.mail.ru", "www.ok.ru", "www.google.es", "www.pages.tmall.com", "www.msn.com", "www.google.com.tr", "www.google.com.au", "www.whatsapp.com", "www.spotify.com", "www.google.pl", "www.google.co.id", "www.xhamster.com", "www.google.com.ar", "www.xnxx.com", "www.google.co.th", "www.Naver.com", "www.sogou.com", "www.samsung.com", "www.accuweather.com", "www.goo.gl", "www.sm.cn", "www.googleweblight.com"]

# %%
import random

data['Refferal'] = ""
data['Refferal'] = data['Refferal'].apply(lambda x: random.choice(ref_list))

# %%
data.head()
# Out:
#    User_ID  Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001       69042      F  0-17          10             A
# 1  1000001      248942      F  0-17          10             A
# 2  1000001       87842      F  0-17          10             A
# 3  1000001       85442      F  0-17          10             A
# 4  1000002      285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase          Refferal
# 0                 NaN                 NaN      8370        www.jd.com
# ...

# %%
# data.to_csv("data/BlackFridayEdit.csv", index=False)

# %%
users = data.drop(["Product_ID", "Product_Category_1", "Product_Category_2", "Product_Category_3", "Purchase"], axis=1)
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 8 columns):
# User_ID                       537577 non-null int64
# Gender                        537577 non-null object
# Age                           537577 non-null object
# Occupation                    537577 non-null int64
# City_Category                 537577 non-null object
# Stay_In_Current_City_Years    537577 non-null object
# Marital_Status                537577 non-null int64
# Refferal                      537577 non-null object
# dtypes: int64(3), object(5)
# memory usage: 32.8+ MB

# %%
products = data[["User_ID", "Product_ID", "Product_Category_1", "Product_Category_2", "Product_Category_3"]]
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 5 columns):
# User_ID               537577 non-null int64
# Product_ID            537577 non-null int64
# Product_Category_1    537577 non-null int64
# Product_Category_2    370591 non-null float64
# Product_Category_3    164278 non-null float64
# dtypes: float64(2), int64(3)
# memory usage: 20.5 MB

# %%
user_purchase = data[["User_ID", "Purchase"]].copy()
user_purchase = user_purchase.groupby("User_ID")["Purchase"].sum().reset_index()
user_purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5891 entries, 0 to 5890
# Data columns (total 2 columns):
# User_ID     5891 non-null int64
# Purchase    5891 non-null int64
# dtypes: int64(2)
# memory usage: 92.1 KB

# %%
users.to_csv("data/users.csv", index=False)
products.to_csv("data/products.csv", index=False)
user_purchase.to_csv("data/user_purchase.csv", index=False)
